# %% [markdown]
# 作業1
#
# Kaggle上我選擇 Supply_Chain 這組dataset
#
# 1. 你選的這組資料為何重要: 利用銷售資料來預測全球supply chain供應數量， 以減少各區域的物流時間，增加客戶體驗.
#
# 2. 資料從何而來:  CCF BDCI. (A Chinese Company)
#
# 3. 蒐集而來的資料型態為何: 結構型資料，包含銷售商品id、名稱、下單量、價格等等
#
# 4. 這組資料想解決的問題如何評估:以購買量當作預測值，其他欄位當作特徵值預測，可能會使用時間序列相關的演算法，來預估不同時間的購買量。

# %% [markdown]
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何: 假設業績為定義車隊所有司機每月收入總合，則問題為如何讓車隊整體每月營收較上月增加，營收多寡是否與司機本生或是跑車區域的人口或車流有關?
#
# 2. 資料從何而來: 收集司機基本資料(年齡,性別)、各縣市或行政區人口(政府公開資料)、每日不同時段交通資訊(車流量)
#
# 3. 蒐集而來的資料型態為何:結構化資料為主如數值型、字串型
#
# 4. 你要回答的問題，其如何評估: 可以by不同縣市分析，以當地司機的年齡性別+車流量找出與營收的相關性，應該會使用回歸相關的演算法。

# %% [markdown]
# 作業3

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_square_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum((y - yp)**2) / len(y)
    return mae

MSE = mean_square_error(y, y_hat)
print("The Mean square error is %.3f" % (MSE))
# Out:
# The Mean square error is 240.592
